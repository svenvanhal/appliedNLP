# %% [markdown]
# ## Compare mutal information gain of the features

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from os import path

data_path = '../features/final_feat'
feature_path = 'features.pkl'
label_path = 'labels.npy'

features = pd.read_pickle(path.join(data_path, feature_path))
labels = np.load(path.join(data_path, label_path))

# %%
import classification
from IPython.display import display

clfs = classification.Classifiers(features,labels,[])

# %% [markdown]
# ## Observation:
# The sklearn mutual_information_gain function function introduces some kind of randomness: adding small noise to continuous variables in order to remove repeated values.
# Thus to have reliable results, we need to repeat this a few times
#
# **IMPORTANT NOTE:** info gain can differ in results as this is a randomised process. Order should be the same!!

# %%
info_gain = clfs.repeat_info_gain(features, repeats=20)

# %%
pd.options.display.max_rows=1000
display(info_gain.loc[:, ['Feature Name', 'Mean']])
# Out:
#                                      Feature Name      Mean
# 1                       numTags{'NNP'}_post_title  0.044927
# 2      ratioTags_{'NNP'}_post_title_article_title  0.038684
# 3               ratioChars_post_title_article_par  0.037527
# 4           ratioChars_article_title_article_desc  0.030285
# 5                             numChars_post_title  0.027414
# 6                    numWordsTitlecase_post_title  0.026940
# 7              ratioChars_post_title_article_desc  0.025994
# 8       ratioTags_{'DT'}_post_title_article_title  0.024696
# 9            ratioChars_article_title_article_par  0.022055
# 10            ratioChars_article_title_article_kw  0.021323
# 11             diffChars_article_title_article_kw  0.018572
# 12                         numChars_article_title  0.018315
# 13            diffChars_article_title_article_par  0.017397
# 14      diffTags_{'NNP'}_post_title_article_title  0.016920
# 15                    numTags{'DT'}_article_title  0.016584
# 16                            numWords_post_title  0.016296
# 17                   numTags{'NNP'}_article_title  0.015630
# 18         diffSentiment_post_title_article_title  0.015590
# 19                      numFormalWords_post_title  0.015438
# 20             ratioChars_article_kw_article_desc  0.015376
# 21   ratioWordsTitlecase_post_title_article_title  0.015342
# 22                       numTags{'DT'}_post_title  0.015076
# 23                        sentiment_article_title  0.014674
# 24               ratioChars_post_title_article_kw  0.014209
# 25            ratioChars_post_title_article_title  0.014204
# 26                 numQuestionMarks_article_title  0.014196
# 27                          numChars_article_desc  0.014117
# 28           diffChars_article_title_article_desc  0.013272
# 29                           sentiment_post_title  0.013128
# 30                           numChars_article_par  0.013115
# 31                         numWords_article_title  0.012943
# 32                    numQuestionMarks_post_title  0.012716
# 33             diffChars_post_title_article_title  0.012228
# 34            ratioWords_post_title_article_title  0.011606
# 35             diffChars_article_desc_article_par  0.010762
# 36               diffChars_article_kw_article_par  0.010684
# 37        ratioStopWords_article_title_post_image  0.010570
# 38              diffChars_article_kw_article_desc  0.010475
# 39               diffChars_post_title_article_par  0.009662
# 40            diffStopWords_post_title_post_image  0.009318
# 41                   numQuestionMarks_article_par  0.009164
# 42              diffChars_post_title_article_desc  0.009141
# 43                   numWordsUppercase_post_title  0.009109
# 44                numWordsTitlecase_article_title  0.008881
# 45             diffChars_article_title_post_image  0.008644
# 46                   numFormalWords_article_title  0.008544
# 47             diffWords_article_title_post_image  0.008496
# 48                      numTags{'PRP'}_post_title  0.008338
# 49              ratioChars_article_kw_article_par  0.008237
# 50               ratioChars_post_image_article_kw  0.008186
# 51                        numStopWords_post_image  0.008038
# 52            ratioChars_article_desc_article_par  0.007790
# 53            ratioWords_article_title_post_image  0.007679
# 54                numWordsUppercase_article_title  0.007624
# 55                     numStopWords_article_title  0.007299
# 56    diffWordsTitlecase_post_title_article_title  0.007294
# 57        ratioStopWords_post_title_article_title  0.007131
# 58            ratioChars_article_title_post_image  0.007105
# 59           ratioStopWords_post_title_post_image  0.007101
# 60         ratioFormalWords_post_title_post_image  0.006839
# 61      ratioFormalWords_post_title_article_title  0.006664
# 62       diffFormalWords_post_title_article_title  0.006497
# 63             ratioChars_post_image_article_desc  0.006342
# 64     ratioTags_{'PRP'}_post_title_article_title  0.006298
# 65                diffWords_post_title_post_image  0.006265
# 66                  numQuestionMarks_article_desc  0.006237
# 67                            numChars_post_image  0.006146
# 68                diffChars_post_title_post_image  0.005755
# 69      ratioFormalWords_article_title_post_image  0.005682
# 70          diffFormalWords_post_title_post_image  0.005443
# 71       diffTags_{'DT'}_post_title_article_title  0.005315
# 72    diffWordsUppercase_article_title_post_image  0.005283
# 73                        numStopWords_post_title  0.005258
# 74                            numWords_post_image  0.005231
# 75       diffFormalWords_article_title_post_image  0.005205
# 76             diffWords_post_title_article_title  0.005177
# 77                   numWordsUppercase_post_image  0.005121
# 78              diffChars_post_image_article_desc  0.005120
# 79         diffStopWords_article_title_post_image  0.005025
# 80      diffTags_{'PRP'}_post_title_article_title  0.004901
# 81                      numFormalWords_post_image  0.004898
# 82                                      isRetweet  0.004754
# 83   ratioWordsUppercase_post_title_article_title  0.004525
# 84              numQuestionMarks_article_keywords  0.004347
# 85                diffChars_post_title_article_kw  0.004268
# 86      ratioWordsTitlecase_post_title_post_image  0.004250
# 87         diffStopWords_post_title_article_title  0.003632
# 88    diffWordsTitlecase_article_title_post_image  0.003517
# 89    diffWordsUppercase_post_title_article_title  0.003482
# 90   ratioWordsUppercase_article_title_post_image  0.003445
# 91                    numQuestionMarks_post_image  0.003401
# 92                            numChars_article_kw  0.003073
# 93               ratioChars_post_title_post_image  0.002618
# 94              ratioChars_post_image_article_par  0.002482
# 95                diffChars_post_image_article_kw  0.002292
# 96                   numTags{'PRP'}_article_title  0.002283
# 97               ratioWords_post_title_post_image  0.002190
# 98      ratioWordsUppercase_post_title_post_image  0.002187
# 99       diffWordsUppercase_post_title_post_image  0.001955
# 100                  numWordsTitlecase_post_image  0.001833
# 101              diffChars_post_image_article_par  0.001763
# 102  ratioWordsTitlecase_article_title_post_image  0.001600
# 103      diffWordsTitlecase_post_title_post_image  0.001292

# %%
# Out:
# 150
